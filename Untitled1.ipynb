# %% [markdown]
# <a href="https://colab.research.google.com/github/JahnaviRamesh/20221CSD0113/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install matplotlib==3.4

# %%
from matplotlib import pyplot as plt
plt.style.use('seaborn-whitegrid')

import numpy as np
print("step 1")
# Out:
# step 1
# <ipython-input-21-240c5389bdd3>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
  fig = plt.figure()
  ax = plt.axes()
  ax.grid()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,1000)
ax.plot(x,np.sin(x),label = 'sin', linestyle = 'dashed')
ax.plot(x,np.cos(x),label = 'cos', linestyle = 'dotted')
ax.plot(x,np.sin (x+1),label = 'sin x+1',Linestyle = 'dashdot')
ax.set_title('MUltiple Lines');
ax.set_xlabel('period')
ax.set_ylabel('amplitute')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9668338dc4a8> in <cell line: 6>()
#       4 ax.plot(x,np.sin(x),label = 'sin', linestyle = 'dashed')
#       5 ax.plot(x,np.cos(x),label = 'cos', linestyle = 'dotted')
# ----> 6 ax.plot(x,np.sin (x+1),label = 'sin x+1',Linestyle = 'dashdot')
#       7 ax.set_title('MUltiple Lines');
#       8 ax.set_xlabel('period')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686             loglog([x], y, [fmt], data=None, **kwargs)
#    1687             loglog([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
# -> 1688
#    1689         This is just a thin wrapper around `.plot` which additionally changes
#    1690         both the x-axis and the y-axis to log scaling. All of the concepts and
#
# ...

# %%
data = {'Apple':10, 'Orange':15, 'Banana':13,
         'Pear':9,'Pomeogranate':11,'Lemon':5,
        'Lime':20}
names = list(data.keys())
values = list(data.values())
ax = plt.axes()
ax.barh(names, values)
# Out:
# <BarContainer object of 7 artists>

# %%
data = {'Apple':10, 'Orange':15, 'Banana':13,
         'Pear':9,'Pomeogranate':11,'Lemon':5,
        'Lime':20}
names = list(data.keys())
values = list(data.values())
ax = plt.axes()
ax.barh(names, values)
ax.set_xlabel('Quantity')
ax.set_ylabel('Fruit')
ax.set_title('Fruit Quantities')
# Out:
# Text(0.5, 1.0, 'Fruit Quantities')

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots()
rectal = ax.bar(x - width/2, men_means)

ax.set_ylabel('Ecores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set
# Out:
# <bound method Axes.set of <Axes: title={'center': 'Scores by group and gender'}, ylabel='Ecores'>>

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots()
rectal = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Ecores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots()
rectal = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Ecores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

ax.set_ylim(0,40);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c7c0859fc1b0> in <cell line: 18>()
#      16 ax.legend();
#      17
# ---> 18 ax.bar_label(rects1, padding=3)
#      19 ax.bar_label(rects2, padding=3)
#      20
#
# NameError: name 'rects1' is not defined
